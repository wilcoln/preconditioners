# %% [markdown]
# Try the same as last time but with stronger regul_lambda to make it further away from the empirical covariance. Even with large regul lambda it does not make a difference. It seems that it is not difficult to make a good approximation of cov_empir such that the resulting preconditioned GD algorithm will have a different limit than GD

# %%
import sys, json
from datetime import datetime as dt
import numpy as np
import scipy
from preconditioners.utils import generate_c, generate_centered_gaussian_data
from preconditioners.impl_cov_approx import *
from sklearn.covariance import  GraphicalLasso

# %%
# parameters of the run
n_epochs = 100
iter_per_epoch = 500
tol = 0.1
n = 50
d = 150
ro = 0.5
regime = 'autoregressive'
regul_lambda = 1000
lr_start = 0.05
lr_decay = 0.98

params = {
    'n_epochs' : n_epochs,
    'iter_per_epoch' : iter_per_epoch,
    'tol' : tol,
    'n' : n,
    'd' : d,
    'ro' : ro,
    'regime' : regime,
    'regul_lambda' : regul_lambda,
    'lr_start' : lr_start,
    'lr_decay' : lr_decay
}

# %%
# generate data and initialization
c = generate_c(ro=ro,
                regime=regime,
                n=n,
                d=d
                )
w_star = np.random.multivariate_normal(mean=np.zeros(d), cov=np.eye(d))
X, y, xi = generate_centered_gaussian_data(w_star,
                                            c,
                                            n=n,
                                            d=d,
                                            sigma2=1,
                                            fix_norm_of_x=False)

# initialize C (cholesky), cov_inv, regul_lambda and learning rate
# is this a good way to initialize?
cov_empir = X.T.dot(X) / n
cov_inv = np.linalg.inv(cov_empir + 0.1 * np.eye(d))
C = scipy.linalg.cholesky(cov_inv) + 0.1 * generate_c(ro=0.1,
                                                        regime='autoregressive',
                                                        n=n,
                                                        d=d,
                                                        )
# Out:
# /Users/eduardoravkin/Dropbox/My Mac (Eduard’s MacBook Pro)/Desktop/ml_research/PhD/preconditioners/src/preconditioners/utils.py:219: UserWarning: Warning, norms of datapoints are not sqrt(d)
#   warnings.warn('Warning, norms of datapoints are not sqrt(d)')

# %%
# run optimization
for epoch in range(n_epochs):
    if epoch == 0:
        lr = lr_start
    else:
        lr = lr * lr_decay

    for i in range(iter_per_epoch):
        # compute loss and gradient
        cov_inv = C.dot(C.T)
        loss_val = loss(cov_inv, X, cov_empir, regul_lambda)
        grad_loss_val = grad_loss(C, cov_empir, regul_lambda, X)
        error = np.linalg.norm(grad_loss_val)

        # update C (+ because we are maximizing)
        C = C + lr * grad_loss_val
        # update regul_lambda
        # regul_lambda = regul_lambda - lr*np.trace(grad_loss_val.dot(grad_loss_val.T))
        # check if we are done
        if i % 50 == 0:
            print(f"iteration {i}/{iter_per_epoch} of epoch {epoch}/{n_epochs}, loss {loss_val} and error {error}")
        if error < tol:
            break

dtstamp = str(dt.now()).replace(' ', '_')
with open(f'results_{dtstamp}.json', 'w') as f:
    json.dump({'C' : C.tolist(), 'loss' : float(loss_val), 'error' : float(error), 'parans' : params}, f)
# Out:
# iteration 0/500 of epoch 0/100, loss -541.9643882944864 and error 119.21085320304746
# iteration 50/500 of epoch 0/100, loss 198.59074469696267 and error 4.708374384920027
# iteration 100/500 of epoch 0/100, loss 242.6208558322092 and error 3.765483375457212
# iteration 150/500 of epoch 0/100, loss 272.9735299889714 and error 3.232254086579383
# iteration 200/500 of epoch 0/100, loss 296.19403634446275 and error 2.8768439093229317
# iteration 250/500 of epoch 0/100, loss 315.01258731203365 and error 2.6179992152419898
# iteration 300/500 of epoch 0/100, loss 330.8380248672936 and error 2.418573562144262
# iteration 350/500 of epoch 0/100, loss 344.49437869853693 and error 2.258802587511555
# iteration 400/500 of epoch 0/100, loss 356.50586625464894 and error 2.127060681282179
# iteration 450/500 of epoch 0/100, loss 367.2268484720718 and error 2.016000572552507
# iteration 0/500 of epoch 1/100, loss 376.9081708758089 and error 1.920719931538273
# iteration 50/500 of epoch 1/100, loss 385.5647930182532 and error 1.839358782981613
# iteration 100/500 of epoch 1/100, loss 393.5311647192169 and error 1.7675434570371127
# iteration 150/500 of epoch 1/100, loss 400.9093437066067 and error 1.7035350081767948
# iteration 200/500 of epoch 1/100, loss 407.78022588266566 and error 1.646003992400176
# iteration 250/500 of epoch 1/100, loss 414.20900794367725 and error 1.5939180292974993
# iteration 300/500 of epoch 1/100, loss 420.24902867408525 and error 1.5464660073327985
# iteration 350/500 of epoch 1/100, loss 425.94452482281076 and error 1.503002195870361
# iteration 400/500 of epoch 1/100, loss 431.3326251045722 and error 1.4630034886636165
# iteration 450/500 of epoch 1/100, loss 436.44480595471117 and error 1.4260382045242532
# iteration 0/500 of epoch 2/100, loss 441.30797565581935 and error 1.3917448060121864
# iteration 50/500 of epoch 2/100, loss 445.8546159087945 and error 1.3604348344348676
# iteration 100/500 of epoch 2/100, loss 450.2032970471422 and error 1.331152045092909
# iteration 150/500 of epoch 2/100, loss 454.37056867752574 and error 1.3036862567186016
# iteration 200/500 of epoch 2/100, loss 458.3709840499281 and error 1.2778564106426413
# iteration 250/500 of epoch 2/100, loss 462.2174085244251 and error 1.2535057547673611
# iteration 300/500 of epoch 2/100, loss 465.92127137709116 and error 1.2304978704839888
# iteration 350/500 of epoch 2/100, loss 469.49277251841795 and error 1.2087134146089948
# iteration 400/500 of epoch 2/100, loss 472.94105326554774 and error 1.1880474562287016
# iteration 450/500 of epoch 2/100, loss 476.2743383498193 and error 1.1684072984310254
# iteration 0/500 of epoch 3/100, loss 479.5000547809884 and error 1.1497106900597185
# iteration 50/500 of epoch 3/100, loss 482.56337271706394 and error 1.1322328367604004
# iteration 100/500 of epoch 3/100, loss 485.53560942330114 and error 1.1155290107500289
# iteration 150/500 of epoch 3/100, loss 488.42202714038 and error 1.0995436781241625
# iteration 200/500 of epoch 3/100, loss 491.2274446355385 and error 1.0842267337652587
# iteration 250/500 of epoch 3/100, loss 493.9562857072839 and error 1.0695328360039789
# iteration 300/500 of epoch 3/100, loss 496.6126212272537 and error 1.0554208387964363
# iteration 350/500 of epoch 3/100, loss 499.20020572814457 and error 1.0418533047950194
# iteration 400/500 of epoch 3/100, loss 501.7225093666869 and error 1.0287960859326026
# iteration 450/500 of epoch 3/100, loss 504.18274594682657 and error 1.016217960666482
# iteration 0/500 of epoch 4/100, loss 506.58389757237353 and error 1.0040903190161958
# iteration 50/500 of epoch 4/100, loss 508.882369168668 and error 0.9926169855353051
# iteration 100/500 of epoch 4/100, loss 511.1291902163045 and error 0.9815282833231243
# iteration 150/500 of epoch 4/100, loss 513.3266315963123 and error 0.9708031844809786
# iteration 200/500 of epoch 4/100, loss 515.4768176095268 and error 0.9604222366722879
# iteration 250/500 of epoch 4/100, loss 517.5817383294616 and error 0.9503674144657879
# iteration 300/500 of epoch 4/100, loss 519.643260680394 and error 0.9406219874763199
# iteration 350/500 of epoch 4/100, loss 521.6631383953968 and error 0.9311704031046804
# iteration 400/500 of epoch 4/100, loss 523.6430209875115 and error 0.9219981820027842
# iteration 450/500 of epoch 4/100, loss 525.5844618492116 and error 0.9130918246628921
# iteration 0/500 of epoch 5/100, loss 527.4889255798789 and error 0.9044387277583421
# iteration 50/500 of epoch 5/100, loss 529.3207541121695 and error 0.8961930626645136
# iteration 100/500 of epoch 5/100, loss 531.1196281049708 and error 0.8881689231500236
# iteration 150/500 of epoch 5/100, loss 532.8867124776234 and error 0.8803565626187447
# iteration 200/500 of epoch 5/100, loss 534.6231114436429 and error 0.8727468245811069
# iteration 250/500 of epoch 5/100, loss 536.329872657387 and error 0.8653310974887926
# iteration 300/500 of epoch 5/100, loss 538.0079910125536 and error 0.8581012737248224
# iteration 350/500 of epoch 5/100, loss 539.6584121269868 and error 0.8510497123046121
# iteration 400/500 of epoch 5/100, loss 541.2820355444292 and error 0.8441692048971637
# iteration 450/500 of epoch 5/100, loss 542.879717680315 and error 0.8374529448230028
# iteration 0/500 of epoch 6/100, loss 544.4522745358206 and error 0.8308944987250476
# iteration 50/500 of epoch 6/100, loss 545.9697514196528 and error 0.8246144754706577
# iteration 100/500 of epoch 6/100, loss 547.4645446223918 and error 0.8184747439250069
# iteration 150/500 of epoch 6/100, loss 548.937322383943 and error 0.812470156620876
# iteration 200/500 of epoch 6/100, loss 550.3887238410097 and error 0.8065958267197274
# iteration 250/500 of epoch 6/100, loss 551.8193606930945 and error 0.8008471112844601
# iteration 300/500 of epoch 6/100, loss 553.2298187509967 and error 0.7952195958458181
# iteration 350/500 of epoch 6/100, loss 554.6206593775315 and error 0.7897090801463704
# iteration 400/500 of epoch 6/100, loss 555.9924208294226 and error 0.7843115649567531
# iteration 450/500 of epoch 6/100, loss 557.3456195083497 and error 0.7790232398705641
# iteration 0/500 of epoch 7/100, loss 558.6807511284491 and error 0.7738404719928209
# iteration 50/500 of epoch 7/100, loss 559.9721087047151 and error 0.7688604366325063
# iteration 100/500 of epoch 7/100, loss 561.2470028622633 and error 0.7639753335329641
# iteration 150/500 of epoch 7/100, loss 562.5058481250849 and error 0.7591821841487738
# iteration 200/500 of epoch 7/100, loss 563.7490435549394 and error 0.7544781391618107
# iteration 250/500 of epoch 7/100, loss 564.9769735110023 and error 0.7498604713603063
# iteration 300/500 of epoch 7/100, loss 566.1900083633851 and error 0.7453265689914336
# iteration 350/500 of epoch 7/100, loss 567.388505163949 and error 0.7408739295511838
# iteration 400/500 of epoch 7/100, loss 568.5728082773104 and error 0.7365001539775645
# iteration 450/500 of epoch 7/100, loss 569.7432499749568 and error 0.7322029412166791
# iteration 0/500 of epoch 8/100, loss 570.9001509949675 and error 0.7279800831339347
# iteration 50/500 of epoch 8/100, loss 572.0210741042758 and error 0.7239117822315009
# iteration 100/500 of epoch 8/100, loss 573.1295720114134 and error 0.7199109377542672
# iteration 150/500 of epoch 8/100, loss 574.225917170125 and error 0.7159757057858378
# iteration 200/500 of epoch 8/100, loss 575.3103731694877 and error 0.7121043122170931
# iteration 250/500 of epoch 8/100, loss 576.3831951143374 and error 0.7082950493845451
# iteration 300/500 of epoch 8/100, loss 577.4446299855584 and error 0.704546272904242
# iteration 350/500 of epoch 8/100, loss 578.4949169814424 and error 0.7008563986882418
# iteration 400/500 of epoch 8/100, loss 579.5342878412625 and error 0.6972239001311996
# iteration 450/500 of epoch 8/100, loss 580.5629671522496 and error 0.6936473054559316
# iteration 0/500 of epoch 9/100, loss 581.581172640928 and error 0.6901251952069632
# iteration 50/500 of epoch 9/100, loss 582.569054841917 and error 0.6867250712917536
# iteration 100/500 of epoch 9/100, loss 583.5472736472932 and error 0.6833747141848437
# iteration 150/500 of epoch 9/100, loss 584.516016284784 and error 0.6800729215061534
# iteration 200/500 of epoch 9/100, loss 585.4754645927696 and error 0.6768185311587336
# iteration 250/500 of epoch 9/100, loss 586.4257952252113 and error 0.6736104196099659
# iteration 300/500 of epoch 9/100, loss 587.3671798468646 and error 0.67044750026149
# iteration 350/500 of epoch 9/100, loss 588.2997853194292 and error 0.667328721902419
# iteration 400/500 of epoch 9/100, loss 589.2237738790598 and error 0.6642530672414925
# iteration 450/500 of epoch 9/100, loss 590.1393033058011 and error 0.6612195515123334
# iteration 0/500 of epoch 10/100, loss 591.0465270853011 and error 0.6582272211485511
# iteration 50/500 of epoch 10/100, loss 591.9276914100395 and error 0.6553338077506888
# iteration 100/500 of epoch 10/100, loss 592.8011592975927 and error 0.6524782190296362
# iteration 150/500 of epoch 10/100, loss 593.6670640340819 and error 0.6496596379516462
# iteration 200/500 of epoch 10/100, loss 594.525535472884 and error 0.6468772719802767
# iteration 250/500 of epoch 10/100, loss 595.376700151496 and error 0.6441303521400845
# iteration 300/500 of epoch 10/100, loss 596.2206814035087 and error 0.6414181321235777
# iteration 350/500 of epoch 10/100, loss 597.0575994658483 and error 0.6387398874392105
# iteration 400/500 of epoch 10/100, loss 597.8875715815819 and error 0.6360949145982314
# iteration 450/500 of epoch 10/100, loss 598.7107120985268 and error 0.6334825303381584
# iteration 0/500 of epoch 11/100, loss 599.5271325637813 and error 0.6309020708813575
# iteration 50/500 of epoch 11/100, loss 600.320809087875 and error 0.6284035743727575
# iteration 100/500 of epoch 11/100, loss 601.1082362167092 and error 0.625934528664881
# iteration 150/500 of epoch 11/100, loss 601.8895115980635 and error 0.6234943596671306
# iteration 200/500 of epoch 11/100, loss 602.6647306087565 and error 0.6210825088355748
# iteration 250/500 of epoch 11/100, loss 603.4339864245238 and error 0.6186984326357431
# iteration 300/500 of epoch 11/100, loss 604.1973700872358 and error 0.6163416020280402
# iteration 350/500 of epoch 11/100, loss 604.9549705695471 and error 0.6140115019744283
# iteration 400/500 of epoch 11/100, loss 605.7068748371627 and error 0.6117076309656461
# iteration 450/500 of epoch 11/100, loss 606.4531679087255 and error 0.609429500567554
# iteration 0/500 of epoch 12/100, loss 607.193932913518 and error 0.6071766349861477
# iteration 50/500 of epoch 12/100, loss 607.9145971154845 and error 0.6049928934229439
# iteration 100/500 of epoch 12/100, loss 608.6301051106443 and error 0.6028325456021889
# iteration 150/500 of epoch 12/100, loss 609.3405301587236 and error 0.6006951767906763
# iteration 200/500 of epoch 12/100, loss 610.0459439691256 and error 0.5985803824765905
# iteration 250/500 of epoch 12/100, loss 610.7464167443426 and error 0.596487768047938
# iteration 300/500 of epoch 12/100, loss 611.4420172219176 and error 0.5944169484832277
# iteration 350/500 of epoch 12/100, loss 612.1328127148686 and error 0.5923675480537415
# iteration 400/500 of epoch 12/100, loss 612.8188691508497 and error 0.5903392000372463
# iteration 450/500 of epoch 12/100, loss 613.5002511098511 and error 0.5883315464422383
# iteration 0/500 of epoch 13/100, loss 614.1770218607217 and error 0.5863442377424756
# iteration 50/500 of epoch 13/100, loss 614.8358427116108 and error 0.5844160861475233
# iteration 100/500 of epoch 13/100, loss 615.4903516986459 and error 0.5825068321086581
# iteration 150/500 of epoch 13/100, loss 616.1406048958567 and error 0.5806161689350634
# iteration 200/500 of epoch 13/100, loss 616.786657290479 and error 0.5787437968596535
# iteration 250/500 of epoch 13/100, loss 617.4285628109014 and error 0.5768894228391093
# iteration 300/500 of epoch 13/100, loss 618.0663743536044 and error 0.5750527603613025
# iteration 350/500 of epoch 13/100, loss 618.7001438094105 and error 0.5732335292592423
# iteration 400/500 of epoch 13/100, loss 619.3299220887424 and error 0.5714314555315863
# iteration 450/500 of epoch 13/100, loss 619.9557591461999 and error 0.5696462711693179
# iteration 0/500 of epoch 14/100, loss 620.5777040043401 and error 0.5678777139882032
# iteration 50/500 of epoch 14/100, loss 621.1834797531003 and error 0.5661604134542656
# iteration 100/500 of epoch 14/100, loss 621.7856081091244 and error 0.5644585989562041
# iteration 150/500 of epoch 14/100, loss 622.3841327317269 and error 0.5627720391342173
# iteration 200/500 of epoch 14/100, loss 622.9790965009655 and error 0.5611005074387687
# iteration 250/500 of epoch 14/100, loss 623.570541536081 and error 0.5594437820031356
# iteration 300/500 of epoch 14/100, loss 624.158509213405 and error 0.5578016455194651
# iteration 350/500 of epoch 14/100, loss 624.7430401837082 and error 0.5561738851189914
# iteration 400/500 of epoch 14/100, loss 625.3241743890716 and error 0.5545602922562534
# iteration 450/500 of epoch 14/100, loss 625.9019510792818 and error 0.552960662596864
# iteration 0/500 of epoch 15/100, loss 626.4764088277022 and error 0.5513747959086325
# iteration 50/500 of epoch 15/100, loss 627.0361936055446 and error 0.5498338111284022
# iteration 100/500 of epoch 15/100, loss 627.5928623710292 and error 0.5483056747450876
# iteration 150/500 of epoch 15/100, loss 628.1464496223285 and error 0.5467902091976218
# iteration 200/500 of epoch 15/100, loss 628.696989287871 and error 0.545287240341635
# iteration 250/500 of epoch 15/100, loss 629.244514738789 and error 0.5437965973651859
# iteration 300/500 of epoch 15/100, loss 629.789058801079 and error 0.5423181127073455
# iteration 350/500 of epoch 15/100, loss 630.3306537673889 and error 0.5408516219789108
# iteration 400/500 of epoch 15/100, loss 630.869331408545 and error 0.5393969638858757
# iteration 450/500 of epoch 15/100, loss 631.4051229847049 and error 0.5379539801546167
# iteration 0/500 of epoch 16/100, loss 631.9380592562737 and error 0.5365225154597585
# iteration 50/500 of epoch 16/100, loss 632.4575954868284 and error 0.5351307096308411
# iteration 100/500 of epoch 16/100, loss 632.9744466057997 and error 0.5337496793862911
# iteration 150/500 of epoch 16/100, loss 633.4886402252673 and error 0.5323792863946175
# iteration 200/500 of epoch 16/100, loss 634.0002035335533 and error 0.5310193947977659
# iteration 250/500 of epoch 16/100, loss 634.5091633038555 and error 0.529669871154548
# iteration 300/500 of epoch 16/100, loss 635.0155459026631 and error 0.5283305843858329
# iteration 350/500 of epoch 16/100, loss 635.5193772979659 and error 0.5270014057209107
# iteration 400/500 of epoch 16/100, loss 636.0206830672126 and error 0.5256822086453835
# iteration 450/500 of epoch 16/100, loss 636.5194884051335 and error 0.5243728688508432
# iteration 0/500 of epoch 17/100, loss 637.0158181313398 and error 0.5230732641854918
# iteration 50/500 of epoch 17/100, loss 637.4998427528529 and error 0.5218089815586341
# iteration 100/500 of epoch 17/100, loss 637.9815359629571 and error 0.5205538221804419
# iteration 150/500 of epoch 17/100, loss 638.4609201134289 and error 0.5193076768506198
# iteration 200/500 of epoch 17/100, loss 638.938017236108 and error 0.5180704381902093
# iteration 250/500 of epoch 17/100, loss 639.4128490490125 and error 0.5168420006024897
# iteration 300/500 of epoch 17/100, loss 639.8854369622694 and error 0.5156222602351679
# iteration 350/500 of epoch 17/100, loss 640.3558020838889 and error 0.514411114943726
# iteration 400/500 of epoch 17/100, loss 640.8239652254521 and error 0.5132084642551658
# iteration 450/500 of epoch 17/100, loss 641.2899469075965 and error 0.5120142093331941
# iteration 0/500 of epoch 18/100, loss 641.7537673654524 and error 0.5108282529440233
# iteration 50/500 of epoch 18/100, loss 642.2062336183953 and error 0.5096739752479352
# iteration 100/500 of epoch 18/100, loss 642.6566619248623 and error 0.508527486965885
# iteration 150/500 of epoch 18/100, loss 643.1050705605893 and error 0.5073887008806385
# iteration 200/500 of epoch 18/100, loss 643.551477556591 and error 0.5062575311362408
# iteration 250/500 of epoch 18/100, loss 643.9959007034806 and error 0.5051338932104992
# iteration 300/500 of epoch 18/100, loss 644.4383575557323 and error 0.5040177038887145
# iteration 350/500 of epoch 18/100, loss 644.8788654358534 and error 0.5029088812375723
# iteration 400/500 of epoch 18/100, loss 645.3174414384437 and error 0.5018073445801278
# iteration 450/500 of epoch 18/100, loss 645.7541024341626 and error 0.5007130144709245
# iteration 0/500 of epoch 19/100, loss 646.1888650736541 and error 0.49962581267210693
# iteration 50/500 of epoch 19/100, loss 646.6131063312861 and error 0.4985671969878582
# iteration 100/500 of epoch 19/100, loss 647.0355554641077 and error 0.49751528187851746
# iteration 150/500 of epoch 19/100, loss 647.4562275492808 and error 0.4964699969545044
# iteration 200/500 of epoch 19/100, loss 647.8751374745302 and error 0.49543127285711236
# iteration 250/500 of epoch 19/100, loss 648.2922999412314 and error 0.49439904123926776
# iteration 300/500 of epoch 19/100, loss 648.707729467555 and error 0.49337323474646966
# iteration 350/500 of epoch 19/100, loss 649.1214403915378 and error 0.4923537869985543
# iteration 400/500 of epoch 19/100, loss 649.53344687393 and error 0.49134063257144694
# iteration 450/500 of epoch 19/100, loss 649.9437629012352 and error 0.49033370697962825
# iteration 0/500 of epoch 20/100, loss 650.3524022884742 and error 0.48933294665887817
# iteration 50/500 of epoch 20/100, loss 650.7512552020218 and error 0.48835812309467813
# iteration 100/500 of epoch 20/100, loss 651.1485236680738 and error 0.4873891023219419
# iteration 150/500 of epoch 20/100, loss 651.5442202252141 and error 0.4864258269979377
# iteration 200/500 of epoch 20/100, loss 651.9383572637502 and error 0.48546824057020943
# iteration 250/500 of epoch 20/100, loss 652.3309470280644 and error 0.4845162872623625
# iteration 300/500 of epoch 20/100, loss 652.7220016189135 and error 0.4835699120607319
# iteration 350/500 of epoch 20/100, loss 653.1115329956507 and error 0.48262906070089273
# iteration 400/500 of epoch 20/100, loss 653.499552978405 and error 0.4816936796546141
# iteration 450/500 of epoch 20/100, loss 653.886073250272 and error 0.4807637161170547
# iteration 0/500 of epoch 21/100, loss 654.2711053593949 and error 0.479839117994266
# iteration 50/500 of epoch 21/100, loss 654.6470038688188 and error 0.47893816816928086
# iteration 100/500 of epoch 21/100, loss 655.0214947340136 and error 0.47804227418818035
# iteration 150/500 of epoch 21/100, loss 655.3945884581077 and error 0.47715138894082276
# iteration 200/500 of epoch 21/100, loss 655.7662954270886 and error 0.47626546592918895
# iteration 250/500 of epoch 21/100, loss 656.1366259115881 and error 0.47538445925746803
# iteration 300/500 of epoch 21/100, loss 656.5055900685325 and error 0.4745083236219544
# iteration 350/500 of epoch 21/100, loss 656.8731979428603 and error 0.47363701430109073
# iteration 400/500 of epoch 21/100, loss 657.239459469137 and error 0.47277048714629494
# iteration 450/500 of epoch 21/100, loss 657.6043844731807 and error 0.47190869857219514
# iteration 0/500 of epoch 22/100, loss 657.9679826736307 and error 0.4710516055474512
# iteration 50/500 of epoch 22/100, loss 658.3230307816727 and error 0.47021616935931154
# iteration 100/500 of epoch 22/100, loss 658.6768228122633 and error 0.46938516247930534
# iteration 150/500 of epoch 22/100, loss 659.0293676213906 and error 0.46855854590646073
# iteration 200/500 of epoch 22/100, loss 659.3806739717442 and error 0.46773628111884985
# /opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py:2146: RuntimeWarning: overflow encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# iteration 250/500 of epoch 22/100, loss inf and error 0.4669183300660834
# iteration 300/500 of epoch 22/100, loss inf and error 0.4661046551619229
# iteration 350/500 of epoch 22/100, loss inf and error 0.46529521927709305
# iteration 400/500 of epoch 22/100, loss inf and error 0.4644899857321367
# iteration 450/500 of epoch 22/100, loss inf and error 0.46368891829026054
# iteration 0/500 of epoch 23/100, loss inf and error 0.4628919811506994
# iteration 50/500 of epoch 23/100, loss inf and error 0.462114956148296
# iteration 100/500 of epoch 23/100, loss inf and error 0.461341831015109
# iteration 150/500 of epoch 23/100, loss inf and error 0.46057257323745776
# iteration 200/500 of epoch 23/100, loss inf and error 0.4598071506802759
# iteration 250/500 of epoch 23/100, loss inf and error 0.4590455315807646
# iteration 300/500 of epoch 23/100, loss inf and error 0.45828768454341495
# iteration 350/500 of epoch 23/100, loss inf and error 0.45753357853417476
# iteration 400/500 of epoch 23/100, loss inf and error 0.4567831828753819
# iteration 450/500 of epoch 23/100, loss inf and error 0.45603646724043456
# iteration 0/500 of epoch 24/100, loss inf and error 0.4552934016484798
# iteration 50/500 of epoch 24/100, loss inf and error 0.45456871030870866
# iteration 100/500 of epoch 24/100, loss inf and error 0.45384746841621226
# iteration 150/500 of epoch 24/100, loss inf and error 0.45312964869260214
# iteration 200/500 of epoch 24/100, loss inf and error 0.45241522416057395
# iteration 250/500 of epoch 24/100, loss inf and error 0.45170416813953673
# iteration 300/500 of epoch 24/100, loss inf and error 0.4509964542415959
# iteration 350/500 of epoch 24/100, loss inf and error 0.45029205636724506
# iteration 400/500 of epoch 24/100, loss inf and error 0.44959094870155425
# iteration 450/500 of epoch 24/100, loss inf and error 0.448893105710032
# iteration 0/500 of epoch 25/100, loss inf and error 0.44819850213475004
# iteration 50/500 of epoch 25/100, loss inf and error 0.4475209096409797
# iteration 100/500 of epoch 25/100, loss inf and error 0.44684638101826146
# iteration 150/500 of epoch 25/100, loss inf and error 0.4461748932460286
# iteration 200/500 of epoch 25/100, loss inf and error 0.4455064235453738
# iteration 250/500 of epoch 25/100, loss inf and error 0.4448409493753741
# iteration 300/500 of epoch 25/100, loss inf and error 0.44417844843020965
# iteration 350/500 of epoch 25/100, loss inf and error 0.4435188986358494
# iteration 400/500 of epoch 25/100, loss inf and error 0.4428622781470712
# iteration 450/500 of epoch 25/100, loss inf and error 0.44220856534435315
# iteration 0/500 of epoch 26/100, loss inf and error 0.44155773883081867
# iteration 50/500 of epoch 26/100, loss inf and error 0.4409227089015596
# iteration 100/500 of epoch 26/100, loss inf and error 0.44029041089370435
# iteration 150/500 of epoch 26/100, loss inf and error 0.43966082527531036
# iteration 200/500 of epoch 26/100, loss inf and error 0.43903393270931185
# iteration 250/500 of epoch 26/100, loss inf and error 0.43840971405111423
# iteration 300/500 of epoch 26/100, loss inf and error 0.43778815034605845
# iteration 350/500 of epoch 26/100, loss inf and error 0.437169222827174
# iteration 400/500 of epoch 26/100, loss inf and error 0.4365529129126224
# iteration 450/500 of epoch 26/100, loss inf and error 0.4359392022034045
# iteration 0/500 of epoch 27/100, loss inf and error 0.43532807248110267
# iteration 50/500 of epoch 27/100, loss inf and error 0.43473165220652676
# iteration 100/500 of epoch 27/100, loss inf and error 0.43413767656844066
# iteration 150/500 of epoch 27/100, loss inf and error 0.4335461289121097
# iteration 200/500 of epoch 27/100, loss inf and error 0.43295699274112465
# iteration 250/500 of epoch 27/100, loss inf and error 0.4323702517155538
# iteration 300/500 of epoch 27/100, loss inf and error 0.4317858896501744
# iteration 350/500 of epoch 27/100, loss inf and error 0.43120389051237856
# iteration 400/500 of epoch 27/100, loss inf and error 0.4306242384204176
# iteration 450/500 of epoch 27/100, loss inf and error 0.43004691764160474
# iteration 0/500 of epoch 28/100, loss inf and error 0.4294719125905801
# iteration 50/500 of epoch 28/100, loss inf and error 0.4289106396284145
# iteration 100/500 of epoch 28/100, loss inf and error 0.4283515614626258
# iteration 150/500 of epoch 28/100, loss inf and error 0.4277946638262426
# iteration 200/500 of epoch 28/100, loss inf and error 0.42723993258184684
# iteration 250/500 of epoch 28/100, loss inf and error 0.4266873537198279
# iteration 300/500 of epoch 28/100, loss inf and error 0.4261369133574243
# iteration 350/500 of epoch 28/100, loss inf and error 0.42558859773648766
# iteration 400/500 of epoch 28/100, loss inf and error 0.4250423932228984
# iteration 450/500 of epoch 28/100, loss inf and error 0.4244982863043919
# iteration 0/500 of epoch 29/100, loss inf and error 0.42395626358958816
# iteration 50/500 of epoch 29/100, loss inf and error 0.4234270907670082
# iteration 100/500 of epoch 29/100, loss inf and error 0.4228998944840143
# iteration 150/500 of epoch 29/100, loss inf and error 0.42237466246673305
# iteration 200/500 of epoch 29/100, loss inf and error 0.4218513825478216
# iteration 250/500 of epoch 29/100, loss inf and error 0.4213300426650708
# iteration 300/500 of epoch 29/100, loss inf and error 0.42081063086045845
# iteration 350/500 of epoch 29/100, loss inf and error 0.42029313527881035
# iteration 400/500 of epoch 29/100, loss inf and error 0.41977754416677476
# iteration 450/500 of epoch 29/100, loss inf and error 0.4192638458717339
# iteration 0/500 of epoch 30/100, loss inf and error 0.41875202884057605
# iteration 50/500 of epoch 30/100, loss inf and error 0.4182522624342265
# iteration 100/500 of epoch 30/100, loss inf and error 0.4177542811010772
# iteration 150/500 of epoch 30/100, loss inf and error 0.417258074239792
# iteration 200/500 of epoch 30/100, loss inf and error 0.4167636313370223
# iteration 250/500 of epoch 30/100, loss inf and error 0.4162709419663344
# iteration 300/500 of epoch 30/100, loss inf and error 0.41577999578746
# iteration 350/500 of epoch 30/100, loss inf and error 0.4152907825452796
# iteration 400/500 of epoch 30/100, loss inf and error 0.4148032920689459
# iteration 450/500 of epoch 30/100, loss inf and error 0.41431751427086816
# iteration 0/500 of epoch 31/100, loss inf and error 0.4138334391461613
# iteration 50/500 of epoch 31/100, loss inf and error 0.41336068800377346
# iteration 100/500 of epoch 31/100, loss inf and error 0.4128895533127355
# iteration 150/500 of epoch 31/100, loss inf and error 0.41242002588221643
# iteration 200/500 of epoch 31/100, loss inf and error 0.41195209659449633
# iteration 250/500 of epoch 31/100, loss inf and error 0.411485756404008
# iteration 300/500 of epoch 31/100, loss inf and error 0.4110209963367174
# iteration 350/500 of epoch 31/100, loss inf and error 0.4105578074895863
# iteration 400/500 of epoch 31/100, loss inf and error 0.4100961810293928
# iteration 450/500 of epoch 31/100, loss inf and error 0.4096361081922577
# iteration 0/500 of epoch 32/100, loss inf and error 0.4091775802832408
# iteration 50/500 of epoch 32/100, loss inf and error 0.4087297136069684
# iteration 100/500 of epoch 32/100, loss inf and error 0.4082833143359588
# iteration 150/500 of epoch 32/100, loss inf and error 0.4078383744746112
# iteration 200/500 of epoch 32/100, loss inf and error 0.40739488608822433
# iteration 250/500 of epoch 32/100, loss inf and error 0.40695284130219217
# iteration 300/500 of epoch 32/100, loss inf and error 0.4065122323018454
# iteration 350/500 of epoch 32/100, loss inf and error 0.4060730513314973
# iteration 400/500 of epoch 32/100, loss inf and error 0.405635290693913
# iteration 450/500 of epoch 32/100, loss inf and error 0.40519894274989143
# iteration 0/500 of epoch 33/100, loss inf and error 0.40476399991766204
# iteration 50/500 of epoch 33/100, loss inf and error 0.4043391120201142
# iteration 100/500 of epoch 33/100, loss inf and error 0.4039155593340056
# iteration 150/500 of epoch 33/100, loss inf and error 0.4034933348808047
# iteration 200/500 of epoch 33/100, loss inf and error 0.40307243173295804
# iteration 250/500 of epoch 33/100, loss inf and error 0.40265284301339865
# iteration 300/500 of epoch 33/100, loss inf and error 0.4022345618949605
# iteration 350/500 of epoch 33/100, loss inf and error 0.40181758160013553
# iteration 400/500 of epoch 33/100, loss inf and error 0.4014018954004834
# iteration 450/500 of epoch 33/100, loss inf and error 0.4009874966161101
# iteration 0/500 of epoch 34/100, loss inf and error 0.40057437861539025
# iteration 50/500 of epoch 34/100, loss inf and error 0.4001707593284676
# iteration 100/500 of epoch 34/100, loss inf and error 0.39976835762949314
# iteration 150/500 of epoch 34/100, loss inf and error 0.399367167408848
# iteration 200/500 of epoch 34/100, loss inf and error 0.39896718259999425
# iteration 250/500 of epoch 34/100, loss inf and error 0.3985683971787502
# iteration 300/500 of epoch 34/100, loss inf and error 0.398170805163006
# iteration 350/500 of epoch 34/100, loss inf and error 0.39777440061223585
# iteration 400/500 of epoch 34/100, loss inf and error 0.39737917762745173
# iteration 450/500 of epoch 34/100, loss inf and error 0.39698513035036054
# iteration 0/500 of epoch 35/100, loss inf and error 0.39659225296343364
# iteration 50/500 of epoch 35/100, loss inf and error 0.3962083626594222
# iteration 100/500 of epoch 35/100, loss inf and error 0.395825584968182
# iteration 150/500 of epoch 35/100, loss inf and error 0.3954439145256342
# iteration 200/500 of epoch 35/100, loss inf and error 0.39506334600396736
# iteration 250/500 of epoch 35/100, loss inf and error 0.3946838741111518
# iteration 300/500 of epoch 35/100, loss inf and error 0.3943054935905773
# iteration 350/500 of epoch 35/100, loss inf and error 0.39392819922092936
# iteration 400/500 of epoch 35/100, loss inf and error 0.3935519858158709
# iteration 450/500 of epoch 35/100, loss inf and error 0.393176848223461
# iteration 0/500 of epoch 36/100, loss inf and error 0.39280278132627844
# iteration 50/500 of epoch 36/100, loss inf and error 0.39243722972555944
# iteration 100/500 of epoch 36/100, loss inf and error 0.3920726967846102
# iteration 150/500 of epoch 36/100, loss inf and error 0.39170917778106196
# iteration 200/500 of epoch 36/100, loss inf and error 0.3913466680233404
# iteration 250/500 of epoch 36/100, loss inf and error 0.39098516285014023
# iteration 300/500 of epoch 36/100, loss inf and error 0.3906246576300938
# iteration 350/500 of epoch 36/100, loss inf and error 0.39026514776185384
# iteration 400/500 of epoch 36/100, loss inf and error 0.3899066286736252
# iteration 450/500 of epoch 36/100, loss inf and error 0.3895490958227998
# iteration 0/500 of epoch 37/100, loss inf and error 0.38919254469615033
# iteration 50/500 of epoch 37/100, loss inf and error 0.3888440728023292
# iteration 100/500 of epoch 37/100, loss inf and error 0.38849653525480793
# iteration 150/500 of epoch 37/100, loss inf and error 0.38814992788556085
# iteration 200/500 of epoch 37/100, loss inf and error 0.38780424655277285
# iteration 250/500 of epoch 37/100, loss inf and error 0.3874594871401799
# iteration 300/500 of epoch 37/100, loss inf and error 0.3871156455572486
# iteration 350/500 of epoch 37/100, loss inf and error 0.3867727177387612
# iteration 400/500 of epoch 37/100, loss inf and error 0.38643069964458016
# iteration 450/500 of epoch 37/100, loss inf and error 0.3860895872597657
# iteration 0/500 of epoch 38/100, loss inf and error 0.38574937659376823
# iteration 50/500 of epoch 38/100, loss inf and error 0.3854168412252709
# iteration 100/500 of epoch 38/100, loss inf and error 0.3850851643486116
# iteration 150/500 of epoch 38/100, loss inf and error 0.3847543422762232
# iteration 200/500 of epoch 38/100, loss inf and error 0.38442437134284774
# iteration 250/500 of epoch 38/100, loss inf and error 0.38409524790488436
# iteration 300/500 of epoch 38/100, loss inf and error 0.3837669683408824
# iteration 350/500 of epoch 38/100, loss inf and error 0.38343952905075623
# iteration 400/500 of epoch 38/100, loss inf and error 0.3831129264560089
# iteration 450/500 of epoch 38/100, loss inf and error 0.3827871569994529
# iteration 0/500 of epoch 39/100, loss inf and error 0.38246221714498574
# iteration 50/500 of epoch 39/100, loss inf and error 0.38214457763352455
# iteration 100/500 of epoch 39/100, loss inf and error 0.38182772820659644
# iteration 150/500 of epoch 39/100, loss inf and error 0.3815116655942456
# iteration 200/500 of epoch 39/100, loss inf and error 0.38119638654544385
# iteration 250/500 of epoch 39/100, loss inf and error 0.3808818878278817
# iteration 300/500 of epoch 39/100, loss inf and error 0.38056816622804573
# iteration 350/500 of epoch 39/100, loss inf and error 0.3802552185507185
# iteration 400/500 of epoch 39/100, loss inf and error 0.37994304161922976
# iteration 450/500 of epoch 39/100, loss inf and error 0.379631632274986
# iteration 0/500 of epoch 40/100, loss inf and error 0.37932098737759457
# iteration 50/500 of epoch 40/100, loss inf and error 0.37901729408480683
# iteration 100/500 of epoch 40/100, loss inf and error 0.3787143290452734
# iteration 150/500 of epoch 40/100, loss inf and error 0.37841208935315473
# iteration 200/500 of epoch 40/100, loss inf and error 0.37811057211871696
# iteration 250/500 of epoch 40/100, loss inf and error 0.3778097744683916
# iteration 300/500 of epoch 40/100, loss inf and error 0.37750969354448743
# iteration 350/500 of epoch 40/100, loss inf and error 0.37721032650527436
# iteration 400/500 of epoch 40/100, loss inf and error 0.3769116705246983
# iteration 450/500 of epoch 40/100, loss inf and error 0.3766137227923393
# iteration 0/500 of epoch 41/100, loss inf and error 0.3763164805134424
# iteration 50/500 of epoch 41/100, loss inf and error 0.3760258648780885
# iteration 100/500 of epoch 41/100, loss inf and error 0.3757359214886448
# iteration 150/500 of epoch 41/100, loss inf and error 0.37544664775755204
# iteration 200/500 of epoch 41/100, loss inf and error 0.3751580411110027
# iteration 250/500 of epoch 41/100, loss inf and error 0.3748700989890018
# iteration 300/500 of epoch 41/100, loss inf and error 0.37458281884535827
# iteration 350/500 of epoch 41/100, loss inf and error 0.37429619814751147
# iteration 400/500 of epoch 41/100, loss inf and error 0.3740102343763593
# iteration 450/500 of epoch 41/100, loss inf and error 0.37372492502633653
# iteration 0/500 of epoch 42/100, loss inf and error 0.37344026760526505
# iteration 50/500 of epoch 42/100, loss inf and error 0.37316193348722154
# iteration 100/500 of epoch 42/100, loss inf and error 0.3728842207796828
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/eduardoravkin/Dropbox/My Mac (Eduard’s MacBook Pro)/Desktop/ml_research/PhD/preconditioners/experiments/implicit_covariance_1300_09mar22/implicit_covariance.ipynb Cell 5' in <cell line: 2>()
#      <a href='vscode-notebook-cell:/Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/experiments/implicit_covariance_1300_09mar22/implicit_covariance.ipynb#ch0000004?line=9'>10</a> cov_inv = C.dot(C.T)
#      <a href='vscode-notebook-cell:/Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/experiments/implicit_covariance_1300_09mar22/implicit_covariance.ipynb#ch0000004?line=10'>11</a> loss_val = loss(cov_inv, X, cov_empir, regul_lambda)
# ---> <a href='vscode-notebook-cell:/Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/experiments/implicit_covariance_1300_09mar22/implicit_covariance.ipynb#ch0000004?line=11'>12</a> grad_loss_val = grad_loss(C, cov_empir, regul_lambda, X)
#      <a href='vscode-notebook-cell:/Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/experiments/implicit_covariance_1300_09mar22/implicit_covariance.ipynb#ch0000004?line=12'>13</a> error = np.linalg.norm(grad_loss_val)
#      <a href='vscode-notebook-cell:/Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/experiments/implicit_covariance_1300_09mar22/implicit_covariance.ipynb#ch0000004?line=14'>15</a> # update C (+ because we are maximizing)
#
# File ~/Dropbox/My Mac (Eduard’s MacBook Pro)/Desktop/ml_research/PhD/preconditioners/src/preconditioners/impl_cov_approx.py:46, in grad_loss(C, cov_empir, regul_lambda, X)
#      <a href='file:///Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/src/preconditioners/impl_cov_approx.py?line=43'>44</a> def grad_loss(C, cov_empir, regul_lambda, X):
#      <a href='file:///Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/src/preconditioners/impl_cov_approx.py?line=44'>45</a>     # using the parametrization cov_inv = CC^T and computing gradient with respect to C
# ---> <a href='file:///Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/src/preconditioners/impl_cov_approx.py?line=45'>46</a>     assert np.linalg.cond(C) < 1 / sys.float_info.epsilon, 'C should be invertible'
#      <a href='file:///Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/src/preconditioners/impl_cov_approx.py?line=46'>47</a>     assert (cov_empir == cov_empir.T).all(), 'cov_empir should be symmetric'
#      <a href='file:///Users/eduardoravkin/Dropbox/My%20Mac%20%28Eduard%E2%80%99s%20MacBook%20Pro%29/Desktop/ml_research/PhD/preconditioners/src/preconditioners/impl_cov_approx.py?line=48'>49</a>     # note there is a minus also inside grad_regul.
#
# File <__array_function__ internals>:180, in cond(*args, **kwargs)
#
# File /opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py:1753, in cond(x, p)
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1750'>1751</a>     raise LinAlgError("cond is not defined on empty arrays")
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1751'>1752</a> if p is None or p == 2 or p == -2:
# -> <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1752'>1753</a>     s = svd(x, compute_uv=False)
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1753'>1754</a>     with errstate(all='ignore'):
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1754'>1755</a>         if p == -2:
#
# File <__array_function__ internals>:180, in svd(*args, **kwargs)
#
# File /opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py:1660, in svd(a, full_matrices, compute_uv, hermitian)
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1656'>1657</a>     gufunc = _umath_linalg.svd_n
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1658'>1659</a> signature = 'D->d' if isComplexType(t) else 'd->d'
# -> <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1659'>1660</a> s = gufunc(a, signature=signature, extobj=extobj)
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1660'>1661</a> s = s.astype(_realType(result_t), copy=False)
#    <a href='file:///opt/anaconda3/envs/preconditioners/lib/python3.9/site-packages/numpy/linalg/linalg.py?line=1661'>1662</a> return s
#
# KeyboardInterrupt:

# %%
c
# Out:
# array([[1.00000000e+00, 5.00000000e-01, 2.50000000e-01, ...,
#         5.60519386e-45, 2.80259693e-45, 1.40129846e-45],
#        [5.00000000e-01, 1.00000000e+00, 5.00000000e-01, ...,
#         1.12103877e-44, 5.60519386e-45, 2.80259693e-45],
#        [2.50000000e-01, 5.00000000e-01, 1.00000000e+00, ...,
#         2.24207754e-44, 1.12103877e-44, 5.60519386e-45],
#        ...,
#        [5.60519386e-45, 1.12103877e-44, 2.24207754e-44, ...,
#         1.00000000e+00, 5.00000000e-01, 2.50000000e-01],
#        [2.80259693e-45, 5.60519386e-45, 1.12103877e-44, ...,
#         5.00000000e-01, 1.00000000e+00, 5.00000000e-01],
#        [1.40129846e-45, 2.80259693e-45, 5.60519386e-45, ...,
#         2.50000000e-01, 5.00000000e-01, 1.00000000e+00]])

# %%
np.linalg.inv(c)
# Out:
# array([[ 1.33333333e+000, -6.66666667e-001, -5.55111512e-017, ...,
#          4.14867685e-061,  2.07433843e-061, -1.03716921e-061],
#        [-6.66666667e-001,  1.66666667e+000, -6.66666667e-001, ...,
#         -5.76344236e-224, -2.88172118e-224,  5.76344236e-224],
#        [ 0.00000000e+000, -6.66666667e-001,  1.66666667e+000, ...,
#         -2.07649895e-207, -1.03824947e-207,  2.07649895e-207],
#        ...,
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          1.66666667e+000, -6.66666667e-001,  1.85037171e-017],
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#         -6.66666667e-001,  1.66666667e+000, -6.66666667e-001],
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          0.00000000e+000, -6.66666667e-001,  1.33333333e+000]])

# %%
C.dot(C.T)
# Out:
# array([[ 1.81260209e+03, -2.99210942e+02, -4.21064928e+01, ...,
#          5.59333106e+01,  1.37193968e+02, -3.22057543e+01],
#        [-2.99210942e+02,  1.71527560e+03, -5.21258523e+02, ...,
#         -5.27331087e-01,  3.92474530e+00, -6.79178212e+01],
#        [-4.21064928e+01, -5.21258523e+02,  1.95339977e+03, ...,
#         -4.29586940e+01, -9.73990995e+01, -2.31519117e+02],
#        ...,
#        [ 5.59333106e+01, -5.27331087e-01, -4.29586940e+01, ...,
#          1.99074961e+03, -3.16946294e+02, -4.52294362e+01],
#        [ 1.37193968e+02,  3.92474530e+00, -9.73990995e+01, ...,
#         -3.16946294e+02,  1.78572124e+03, -4.52797408e+02],
#        [-3.22057543e+01, -6.79178212e+01, -2.31519117e+02, ...,
#         -4.52294362e+01, -4.52797408e+02,  1.68545442e+03]])

# %%
np.linalg.inv(C.dot(C.T))
# Out:
# array([[ 1.00663573,  0.530494  ,  0.17644185, ..., -0.16680783,
#         -0.10345324,  0.09956663],
#        [ 0.530494  ,  1.53609714,  0.91136137, ..., -0.01643978,
#         -0.13304121,  0.0951468 ],
#        [ 0.17644185,  0.91136137,  1.27367671, ...,  0.03067205,
#          0.07251723,  0.30137341],
#        ...,
#        [-0.16680783, -0.01643978,  0.03067205, ...,  0.96090307,
#          0.45943137,  0.18018207],
#        [-0.10345324, -0.13304121,  0.07251723, ...,  0.45943137,
#          1.01381038,  0.56018859],
#        [ 0.09956663,  0.0951468 ,  0.30137341, ...,  0.18018207,
#          0.56018859,  1.27247214]])

# %%
cov_empir
# Out:
# array([[ 1.00643195,  0.53051948,  0.17643347, ..., -0.16682012,
#         -0.10348244,  0.09957169],
#        [ 0.53051948,  1.5358976 ,  0.91143317, ..., -0.01643559,
#         -0.1330344 ,  0.09515347],
#        [ 0.17643347,  0.91143317,  1.27344689, ...,  0.03068474,
#          0.07252151,  0.30139127],
#        ...,
#        [-0.16682012, -0.01643559,  0.03068474, ...,  0.96066331,
#          0.45948199,  0.1801907 ],
#        [-0.10348244, -0.1330344 ,  0.07252151, ...,  0.45948199,
#          1.01354976,  0.56021577],
#        [ 0.09957169,  0.09515347,  0.30139127, ...,  0.1801907 ,
#          0.56021577,  1.27225556]])

# %%
gl = GraphicalLasso(assume_centered=True, alpha=0.25, tol=1e-4).fit(X)

# %%
gl.precision_
# Out:
# array([[ 1.08597124, -0.18948688, -0.        , ...,  0.        ,
#          0.        , -0.        ],
#        [-0.18948688,  0.91331423, -0.41805074, ...,  0.        ,
#          0.        , -0.        ],
#        [-0.        , -0.41805074,  1.22116199, ..., -0.        ,
#         -0.        , -0.03802007],
#        ...,
#        [ 0.        ,  0.        , -0.        , ...,  1.24520066,
#         -0.21546217, -0.        ],
#        [ 0.        ,  0.        , -0.        , ..., -0.21546217,
#          1.14718273, -0.26013489],
#        [-0.        , -0.        , -0.03802007, ..., -0.        ,
#         -0.26013489,  0.8875395 ]])
